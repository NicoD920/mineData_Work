# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoD920/mineData_Work/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import pandas as pd

#file_path = '/content/drive/MyDrive/Universidad/5Año-2Semestre/Minería de Datos/Work/archive/beer_reviews.csv'
#data = pd.read_csv(file_path)

# %%
#print(data)

# %%
#url_1 = 'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_1.csv'
#url_2 = 'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_2.csv'
#url_3 = 'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_3.csv'
#url_4 = 'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_4.csv'
#url_5 = 'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_5.csv'
#url_6 = 'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_6.csv'
#url_7 = 'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_7.csv'
#url_8 = 'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_8.csv'
#url_9 = 'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_9.csv'
#data_1 = pd.read_csv(url_1,sep=",", encoding="UTF-8")
#data_2 = pd.read_csv(url_2,sep=",", encoding="UTF-8")
#data_3 = pd.read_csv(url_3,sep=",", encoding="UTF-8")
#data_4 = pd.read_csv(url_4,sep=",", encoding="UTF-8")
#data_5 = pd.read_csv(url_5,sep=",", encoding="UTF-8")
#data_6 = pd.read_csv(url_6,sep=",", encoding="UTF-8")
#data_7 = pd.read_csv(url_7,sep=",", encoding="UTF-8")
#data_8 = pd.read_csv(url_8,sep=",", encoding="UTF-8")
#data_9 = pd.read_csv(url_9,sep=",", encoding="UTF-8")

# %%
import pandas as pd

urls = [
    'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_1.csv',
    'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_2.csv',
    'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_3.csv',
    'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_4.csv',
    'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_5.csv',
    'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_6.csv',
    'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_7.csv',
    'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_8.csv',
    'https://raw.githubusercontent.com/NicoD920/mineData_Work/main/data/parte_9.csv'
]

# Crear una lista para almacenar los DataFrames
dataframes = []

# Leer los archivos CSV y agregar los DataFrames a la lista
for url in urls:
    data = pd.read_csv(url, sep=",", encoding="UTF-8")
    dataframes.append(data)

# Concatenar los DataFrames en uno solo
df = pd.concat(dataframes, ignore_index=True)
df_puro = df

# Imprimir las primeras filas del DataFrame resultante
print(df.head())
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# ...

# %%
df.describe()
# Out:
#          brewery_id   review_time  review_overall  review_aroma  \
# count  1.586614e+06  1.586614e+06    1.586614e+06  1.586614e+06
# mean   3.130099e+03  1.224089e+09    3.815581e+00  3.735636e+00
# std    5.578104e+03  7.654427e+07    7.206219e-01  6.976167e-01
# min    1.000000e+00  8.406720e+08    0.000000e+00  1.000000e+00
# 25%    1.430000e+02  1.173224e+09    3.500000e+00  3.500000e+00
# 50%    4.290000e+02  1.239203e+09    4.000000e+00  4.000000e+00
# 75%    2.372000e+03  1.288568e+09    4.500000e+00  4.000000e+00
# max    2.800300e+04  1.326285e+09    5.000000e+00  5.000000e+00
#
#        review_appearance  review_palate  review_taste      beer_abv  \
# count       1.586614e+06   1.586614e+06  1.586614e+06  1.518829e+06
# mean        3.841642e+00   3.743701e+00  3.792860e+00  7.042387e+00
# std         6.160928e-01   6.822184e-01  7.319696e-01  2.322526e+00
# min         0.000000e+00   1.000000e+00  1.000000e+00  1.000000e-02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   brewery_id          1586614 non-null  int64
#  1   brewery_name        1586599 non-null  object
#  2   review_time         1586614 non-null  int64
#  3   review_overall      1586614 non-null  float64
#  4   review_aroma        1586614 non-null  float64
#  5   review_appearance   1586614 non-null  float64
#  6   review_profilename  1586266 non-null  object
#  7   beer_style          1586614 non-null  object
#  8   review_palate       1586614 non-null  float64
#  9   review_taste        1586614 non-null  float64
#  10  beer_name           1586614 non-null  object
#  11  beer_abv            1518829 non-null  float64
#  12  beer_beerid         1586614 non-null  int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 157.4+ MB

# %%
df = df.drop('review_profilename', axis=1)

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   brewery_id         1586614 non-null  int64
#  1   brewery_name       1586599 non-null  object
#  2   review_time        1586614 non-null  int64
#  3   review_overall     1586614 non-null  float64
#  4   review_aroma       1586614 non-null  float64
#  5   review_appearance  1586614 non-null  float64
#  6   beer_style         1586614 non-null  object
#  7   review_palate      1586614 non-null  float64
#  8   review_taste       1586614 non-null  float64
#  9   beer_name          1586614 non-null  object
#  10  beer_abv           1518829 non-null  float64
#  11  beer_beerid        1586614 non-null  int64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 145.3+ MB
#          brewery_id   review_time  review_overall  review_aroma  \
# ...

# %%
print(df.head())
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance                      beer_style  \
# 0           2.0                2.5                      Hefeweizen
# 1           2.5                3.0              English Strong Ale
# 2           2.5                3.0          Foreign / Export Stout
# 3           3.0                3.5                 German Pilsener
# 4           4.5                4.0  American Double / Imperial IPA
#
#    review_palate  review_taste               beer_name  beer_abv  beer_beerid
# ...

# %%
import pandas as pd

# Obtener niveles únicos y asignar valores numéricos únicos para 'brewery_name'
niveles_unicos_breweryname = df['brewery_name'].unique()
valores_numericos_breweryname = list(range(1, len(niveles_unicos_breweryname) + 1))

# Crear un DataFrame con la correspondencia para 'brewery_name'
correspondencia_df_breweryname = pd.DataFrame({'categoria': niveles_unicos_breweryname, 'valor_numerico': valores_numericos_breweryname})

# Reemplazar la columna categórica por la columna numérica en el DataFrame original para 'brewery_name'
df['brewery_name'] = df['brewery_name'].map(correspondencia_df_breweryname.set_index('categoria')['valor_numerico'])

# Repetir el proceso para 'beer_style'
niveles_unicos_beerstyle = df['beer_style'].unique()
valores_numericos_beerstyle = list(range(1, len(niveles_unicos_beerstyle) + 1))
correspondencia_df_beerstyle = pd.DataFrame({'categoria': niveles_unicos_beerstyle, 'valor_numerico': valores_numericos_beerstyle})
df['beer_style'] = df['beer_style'].map(correspondencia_df_beerstyle.set_index('categoria')['valor_numerico'])

# Repetir el proceso para 'beer_name'
niveles_unicos_beername = df['beer_name'].unique()
valores_numericos_beername = list(range(1, len(niveles_unicos_beername) + 1))
correspondencia_df_beername = pd.DataFrame({'categoria': niveles_unicos_beername, 'valor_numerico': valores_numericos_beername})
df['beer_name'] = df['beer_name'].map(correspondencia_df_beername.set_index('categoria')['valor_numerico'])

# %%
print(df.head())
# Out:
#    brewery_id  brewery_name  review_time  review_overall  review_aroma  \
# 0       10325             1   1234817823             1.5           2.0
# 1       10325             1   1235915097             3.0           2.5
# 2       10325             1   1235916604             3.0           2.5
# 3       10325             1   1234725145             3.0           3.0
# 4        1075             2   1293735206             4.0           4.5
#
#    review_appearance  beer_style  review_palate  review_taste  beer_name  \
# 0                2.5           1            1.5           1.5          1
# 1                3.0           2            3.0           3.0          2
# 2                3.0           3            3.0           3.0          3
# 3                3.5           4            2.5           3.0          4
# 4                4.0           5            4.0           4.5          5
#
#    beer_abv  beer_beerid
# 0       5.0        47986
# 1       6.2        48213
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   brewery_id         1586614 non-null  int64
#  1   brewery_name       1586614 non-null  int64
#  2   review_time        1586614 non-null  int64
#  3   review_overall     1586614 non-null  float64
#  4   review_aroma       1586614 non-null  float64
#  5   review_appearance  1586614 non-null  float64
#  6   beer_style         1586614 non-null  int64
#  7   review_palate      1586614 non-null  float64
#  8   review_taste       1586614 non-null  float64
#  9   beer_name          1586614 non-null  int64
#  10  beer_abv           1518829 non-null  float64
#  11  beer_beerid        1586614 non-null  int64
# dtypes: float64(6), int64(6)
# memory usage: 145.3 MB
#          brewery_id  brewery_name   review_time  review_overall  review_aroma  \
# ...

# %%
print(len(valores_numericos_breweryname))
print(len(valores_numericos_beerstyle))
print(len(valores_numericos_beername))
# Out:
# 5743
# 104
# 56857

# %% [markdown]
# ### Información importante
# Tenemos que las variables "brewery_name", "beer_style" y "beer_name" son variables del tipo catergóricas pero en este caso las hemos etiquetado como numéricas para facilitar el análisis. Hemos guardado la información de a que corresponde cada etiqueta para un posterior análisis.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Calcula la matriz de correlaciones
correlation_matrix = df.corr()

# Configura el estilo de seaborn
sns.set(style='white')

# Crea un mapa de calor de las correlaciones
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Mapa de Correlaciones')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.histplot(data=df, x='review_overall', bins=20, kde=True)
plt.title('Histograma de review_overall')
plt.xlabel('Valor de review_overall')
plt.ylabel('Frecuencia')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supongamos que 'df' es tu DataFrame y deseas visualizar la relación entre 'review_overall' y 'beer_style'.

plt.figure(figsize=(25, 8))
ax = sns.barplot(data=df, x='beer_style', y='review_overall')
plt.title('Relación entre review_overall y beer_style')
plt.xlabel('Estilo de cerveza (beer_style)')
plt.ylabel('Valor de review_overall')
plt.xticks(rotation=90)

# Obtén el valor máximo de las puntuaciones de revisión
max_review_value = 4

# Agrega una línea horizontal en el valor máximo
ax.axhline(max_review_value, color='red', linestyle='--', label='Valor referencia')
plt.legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supongamos que 'df' es tu DataFrame y deseas visualizar la relación entre 'review_overall' y 'beer_style'.

plt.figure(figsize=(6, 6))
ax = sns.barplot(data=df, x='review_aroma', y='review_overall')
plt.title('Relación entre review_overall y review_aroma')
plt.xlabel('Estilo de cerveza (beer_style)')
plt.ylabel('Valor de review_overall')
plt.xticks(rotation=90)

# Obtén el valor máximo de las puntuaciones de revisión
max_review_value = 4

# Agrega una línea horizontal en el valor máximo
ax.axhline(max_review_value, color='red', linestyle='--', label='Valor referencia')
plt.legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supongamos que 'df' es tu DataFrame y deseas visualizar la relación entre 'review_overall' y 'beer_style'.

plt.figure(figsize=(6, 6))
ax = sns.barplot(data=df, x='review_appearance', y='review_overall')
plt.title('Relación entre review_overall y review_appearance')
plt.xlabel('Estilo de cerveza (beer_style)')
plt.ylabel('Valor de review_overall')
plt.xticks(rotation=90)

# Obtén el valor máximo de las puntuaciones de revisión
max_review_value = 4

# Agrega una línea horizontal en el valor máximo
ax.axhline(max_review_value, color='red', linestyle='--', label='Valor referencia')
plt.legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supongamos que 'df' es tu DataFrame y deseas visualizar la relación entre 'review_overall' y 'beer_style'.

plt.figure(figsize=(6, 6))
ax = sns.barplot(data=df, x='review_aroma', y='review_overall')
plt.title('Relación entre review_overall y review_aroma')
plt.xlabel('Estilo de cerveza (beer_style)')
plt.ylabel('Valor de review_overall')
plt.xticks(rotation=90)

# Obtén el valor máximo de las puntuaciones de revisión
max_review_value = 4

# Agrega una línea horizontal en el valor máximo
ax.axhline(max_review_value, color='red', linestyle='--', label='Valor referencia')
plt.legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supongamos que 'df' es tu DataFrame y deseas visualizar la relación entre 'review_overall' y 'beer_style'.

plt.figure(figsize=(6, 6))
ax = sns.barplot(data=df, x='review_palate', y='review_overall')
plt.title('Relación entre review_overall y review_palate')
plt.xlabel('Estilo de cerveza (beer_style)')
plt.ylabel('Valor de review_overall')
plt.xticks(rotation=90)

# Obtén el valor máximo de las puntuaciones de revisión
max_review_value = 4

# Agrega una línea horizontal en el valor máximo
ax.axhline(max_review_value, color='red', linestyle='--', label='Valor referencia')
plt.legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supongamos que 'df' es tu DataFrame y deseas visualizar la relación entre 'review_overall' y 'beer_style'.

plt.figure(figsize=(6, 6))
ax = sns.barplot(data=df, x='review_taste', y='review_overall')
plt.title('Relación entre review_overall y review_taste')
plt.xlabel('Estilo de cerveza (beer_style)')
plt.ylabel('Valor de review_overall')
plt.xticks(rotation=90)

# Obtén el valor máximo de las puntuaciones de revisión
max_review_value = 4

# Agrega una línea horizontal en el valor máximo
ax.axhline(max_review_value, color='red', linestyle='--', label='Valor referencia')
plt.legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supongamos que 'df' es tu DataFrame y deseas visualizar la relación entre 'review_overall' y 'beer_style'.

plt.figure(figsize=(6, 6))
ax = sns.barplot(data=df, x='review_taste', y='review_overall')
plt.title('Relación entre review_overall y review_taste')
plt.xlabel('Estilo de cerveza (beer_style)')
plt.ylabel('Valor de review_overall')
plt.xticks(rotation=90)

# Obtén el valor máximo de las puntuaciones de revisión
max_review_value = 4

# Agrega una línea horizontal en el valor máximo
ax.axhline(max_review_value, color='red', linestyle='--', label='Valor referencia')
plt.legend()

plt.show()

# %%
df.nunique()
# Out:
# brewery_id              5840
# brewery_name            5743
# review_time          1577960
# review_overall            10
# review_aroma               9
# review_appearance         10
# beer_style               104
# review_palate              9
# review_taste               9
# beer_name              56857
# beer_abv                 530
# beer_beerid            66055
# dtype: int64

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))
plt.scatter( df['review_overall'],df['beer_abv'], alpha=0.3)
plt.title('Relación entre review_overall y beer_abv')
plt.ylabel('Contenido de Alcohol por Volumen (beer_abv)')
plt.xlabel('Valor de review_overall')
plt.axhline(4, color='red', linestyle='--', label='Valor referencia')
plt.legend()
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='review_overall', y='beer_abv')
plt.title('Relación entre review_overall y beer_abv')
plt.xlabel('Puntuación de la reseña (review_overall)')
plt.ylabel('Contenido de Alcohol por Volumen (beer_abv)')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Supongamos que 'df' es tu DataFrame original.

# Copia las columnas categóricas al nuevo DataFrame df_norm
df_norm = df[['brewery_name', 'beer_style', 'beer_name']].copy()

# Normaliza las columnas numéricas (excepto las categóricas) en df_norm
numeric_columns = [col for col in df.columns if col not in ['brewery_name', 'beer_style', 'beer_name']]
scaler = StandardScaler()
df_norm[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# Muestra las primeras filas de df_norm
print(df_norm.head())
# Out:
#    brewery_name  beer_style  beer_name  brewery_id  review_time  \
# 0             1           1          1    1.289847     0.140161
# 1             1           2          2    1.289847     0.154496
# 2             1           3          3    1.289847     0.154516
# 3             1           4          4    1.289847     0.138951
# 4             2           5          5   -0.368423     0.909878
#
#    review_overall  review_aroma  review_appearance  review_palate  \
# 0       -3.213310     -2.487952          -2.177663      -3.288833
# 1       -1.131774     -1.771225          -1.366096      -1.090123
# 2       -1.131774     -1.771225          -1.366096      -1.090123
# 3       -1.131774     -1.054499          -0.554530      -1.823026
# 4        0.255917      1.095679           0.257037       0.375684
#
#    review_taste  beer_abv  beer_beerid
# 0     -3.132454 -0.879382     1.204180
# 1     -1.083188 -0.362703     1.214585
# 2     -1.083188 -0.233533     1.214676
# ...

# %%
df_norm.info()
df_norm.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   brewery_name       1586614 non-null  int64
#  1   beer_style         1586614 non-null  int64
#  2   beer_name          1586614 non-null  int64
#  3   brewery_id         1586614 non-null  float64
#  4   review_time        1586614 non-null  float64
#  5   review_overall     1586614 non-null  float64
#  6   review_aroma       1586614 non-null  float64
#  7   review_appearance  1586614 non-null  float64
#  8   review_palate      1586614 non-null  float64
#  9   review_taste       1586614 non-null  float64
#  10  beer_abv           1518829 non-null  float64
#  11  beer_beerid        1586614 non-null  float64
# dtypes: float64(9), int64(3)
# memory usage: 145.3 MB
#        brewery_name    beer_style     beer_name    brewery_id   review_time  \
# ...
